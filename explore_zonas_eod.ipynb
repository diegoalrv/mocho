# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
zonas_path = './data/05CLBB_Zonificacion_EOD'
zonas = gpd.read_file(zonas_path)
zonas.to_crs(4326, inplace=True)

# %%
zonas.plot(column='CARACT', figsize=(10, 10))
# Out:
# <Axes: >
